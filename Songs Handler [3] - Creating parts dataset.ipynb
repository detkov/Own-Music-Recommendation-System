# %%
import pandas as pd
import numpy as np
import ast
import os
import re

# %%
songs = pd.read_csv('songs_dataset.csv', index_col=0)
songs.head()
# Out:
#         Author               Album                            Song Featuring  \
# 0  $uicideBoy$  7th or St. Tammany              7th or St. Tammany        []
# 1  $uicideBoy$  7th or St. Tammany                  Dead Batteries        []
# 2  $uicideBoy$  7th or St. Tammany  I’ll Pay for It (If I Want It)        []
# 3  $uicideBoy$  7th or St. Tammany   That’s Very Minimalist of You        []
# 4  $uicideBoy$  7th or St. Tammany                         Romulus        []
#
#                                               Lyrics
# 0  \n\nUh\n*59, yah!\nUhhhh, [?]\n*59 motherfucke...
# 1  \n\n[Produced by Budd Dwyer]\n\n[Intro: Frayse...
# 2  \n\n[Verse 1: RUBY DA CHERRY]\nFucking Ruby go...
# 3  \n\n[Verse 1: RUBY DA CHERRY]\nRuby casting sh...
# 4  \n\n[Intro: YUNG HANK MOODY]\nGrey*59\nGrey*59...

# %%
songs.shape
# Out:
# (51343, 5)

# %%
with open ('singers_.txt', 'w') as file:
    file.write("\n".join(songs['Author'].unique().tolist()))

# %%
def get_part_lyrics(part):
    part = part[1:]
    return '\n'.join(part)

# %%
def get_part_info(part, all_singers, author, album, song):
    singer = None
    brackets = part[0]
    brackets_parts = re.split(':|—', brackets[1:-1])
#     brackets_parts = brackets[1:-1].split(':')
    if len(brackets_parts) == 1:
        singer = all_singers[0]
        part_name = brackets_parts[0]
    else:
        part_singers = brackets_parts[1]
        part_singers = list(map(str.strip, re.split(',|&', part_singers)))
        for part_singer in part_singers:
            if part_singer in all_singers:
                singer = part_singer
                break
        part_name = brackets_parts[0]
    part_lyrics = get_part_lyrics(part)
    if not singer:
        singer = author
    if part_lyrics == '':
        return None
    return [author, album, song, all_singers, singer, part_name, brackets[1:-1], part_lyrics]

# %%
def get_parts_from_song(song):
    feats = ast.literal_eval(song['Featuring'])
    author, album, song, _, lyrics = song.values
    all_singers = [author] + feats
#     print(author, '-', album, '-', song, '-', feats, '-', all_singers)
    
    indices = [i for i, ltr in enumerate(lyrics) if ltr == '[' 
                                                and lyrics[i-1] == '\n'
                                                and lyrics[i-2] == '\n'] + [len(lyrics)]
    song_parts = [lyrics[indices[i]:indices[i+1]].strip().split('\n') for i, index in enumerate(indices[:-1])]
    song_parts_info = [get_part_info(song_part, all_singers, author, album, song) for song_part in song_parts]
    song_parts_info = list(filter(None, song_parts_info))

    df = pd.DataFrame(song_parts_info, columns=['Author', 'Album', 'Song', 'All Singers', 
                                                'Part Singer', 'Part Name', 'Part Debug', 'Part Lyrics'])
    return df

# %%
# %%time
parts = songs.apply(get_parts_from_song, axis=1)
parts = pd.concat(parts.tolist(), axis=0)
parts.reset_index(drop=True, inplace=True)
# Out:
# Wall time: 1min 4s

# %%
parts.head()
# Out:
#         Author               Album            Song    All Singers  \
# 0  $uicideBoy$  7th or St. Tammany  Dead Batteries  [$uicideBoy$]
# 1  $uicideBoy$  7th or St. Tammany  Dead Batteries  [$uicideBoy$]
# 2  $uicideBoy$  7th or St. Tammany  Dead Batteries  [$uicideBoy$]
# 3  $uicideBoy$  7th or St. Tammany  Dead Batteries  [$uicideBoy$]
# 4  $uicideBoy$  7th or St. Tammany  Dead Batteries  [$uicideBoy$]
#
#    Part Singer Part Name                          Part Debug  \
# 0  $uicideBoy$     Intro                  Intro: Frayser Boy
# 1  $uicideBoy$   Verse 1        Verse 1: YUNG DEATH/LIL LIFE
# 2  $uicideBoy$      Hook                   Hook: Frayser Boy
# 3  $uicideBoy$   Verse 2  Verse 2: ODDY NUFF DA $NOW LEOPARD
# 4  $uicideBoy$      Hook                   Hook: Frayser Boy
#
#                                          Part Lyrics
# 0  Hit the, hit the, hit the—\nHit the tone, cock...
# 1  Bitches know I got the vendetta\nRollin' up th...
# 2  Hit the tone, cock it back, ho, I gotta holla ...
# 3  Here I come to paint it grey\nWhip look like I...
# 4  Hit the tone, cock it back, ho, I gotta holla ...

# %%
parts.shape
# Out:
# (264227, 8)

# %%
parts.to_csv('parts_dataset.csv')

# %% [markdown]
# ##### "bad" text will convert into np.nan by itself while saving to csv so we can handle it

# %%
parts = pd.read_csv('parts_dataset.csv', index_col=0)
parts['Part Name'] = parts['Part Name'].replace(to_replace={np.nan: 'Verse'})
parts['Part Debug'] = parts['Part Debug'].replace(to_replace={np.nan: ''})
indices_to_drop = parts[parts['Part Lyrics'].apply(lambda x: len(x.split('\n'))) == 1].index
parts.drop(indices_to_drop, inplace=True)
parts.reset_index(drop=True, inplace=True)
parts.head()
# Out:
#         Author               Album            Song      All Singers  \
# 0  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 1  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 2  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 3  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 4  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
#
#    Part Singer Part Name                          Part Debug  \
# 0  $uicideBoy$     Intro                  Intro: Frayser Boy
# 1  $uicideBoy$   Verse 1        Verse 1: YUNG DEATH/LIL LIFE
# 2  $uicideBoy$      Hook                   Hook: Frayser Boy
# 3  $uicideBoy$   Verse 2  Verse 2: ODDY NUFF DA $NOW LEOPARD
# 4  $uicideBoy$      Hook                   Hook: Frayser Boy
#
#                                          Part Lyrics
# 0  Hit the, hit the, hit the—\nHit the tone, cock...
# 1  Bitches know I got the vendetta\nRollin' up th...
# 2  Hit the tone, cock it back, ho, I gotta holla ...
# 3  Here I come to paint it grey\nWhip look like I...
# 4  Hit the tone, cock it back, ho, I gotta holla ...

# %%
parts.shape
# Out:
# (255930, 8)

# %%
def format_part_name(part_name):
    if pd.isna(part_name):
        return ''
    part_name = re.sub('[-–—— ]+', ' ', part_name)
    part_name = part_name.strip()
    part_name = part_name.lower()
    return part_name

parts['Part Name 2'] = parts['Part Name'].apply(lambda x: format_part_name(x))
parts.head()
# Out:
#         Author               Album            Song      All Singers  \
# 0  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 1  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 2  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 3  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 4  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
#
#    Part Singer Part Name                          Part Debug  \
# 0  $uicideBoy$     Intro                  Intro: Frayser Boy
# 1  $uicideBoy$   Verse 1        Verse 1: YUNG DEATH/LIL LIFE
# 2  $uicideBoy$      Hook                   Hook: Frayser Boy
# 3  $uicideBoy$   Verse 2  Verse 2: ODDY NUFF DA $NOW LEOPARD
# 4  $uicideBoy$      Hook                   Hook: Frayser Boy
#
#                                          Part Lyrics Part Name 2
# 0  Hit the, hit the, hit the—\nHit the tone, cock...       intro
# 1  Bitches know I got the vendetta\nRollin' up th...     verse 1
# 2  Hit the tone, cock it back, ho, I gotta holla ...        hook
# 3  Here I come to paint it grey\nWhip look like I...     verse 2
# 4  Hit the tone, cock it back, ho, I gotta holla ...        hook

# %%
def generalize_part_name(in_part_name):
    other_ = ['collision', 'spoken word', 'drop', 'spoken', 'talking', 'solo', '?', 'interview', 'inaudioble',
              'break', 'breakdown', 'sample', 'all', 'pre verse', 'both', 'instrumental', 'voicemail', 
              'dialogue', 'ad libs', 'singer', 'poet', 'man', 'instrumentale', 'pause', 'refarin',
              'pont', 'Other']
    intro_ = ['интро', 'интерлюдия', 'intro', 'into', 'interlude', 'introduction', 'Intro']
    outro_ = ['аутро', 'завершение', 'outro', 'Outro']
    bridge_ = ['бридж', 'переход', 'puente', 'bridge', 'brige', 'Bridge']
    hook_ = ['хук', 'hook', 'Hook']
    skit_ = ['скит', 'skit', 'Skit']
    refrain_ = ['рефрен', 'refrain', 'Refrain']
    chorus_ = ['припев', 'estribillo', 'ritornello', 'coro', 'chorus', 'chrous', 'Chorus']
    verse_ = ['куплет', 'strophe', 'couplet', 'verso', 'verse', 'Verse']
    
    part_names_variations = {'Other': other_, 
                             'Intro': intro_, 
                             'Outro': outro_, 
                             'Bridge': bridge_, 
                             'Hook': hook_, 
                             'Skit': skit_, 
                             'Refrain': refrain_, 
                             'Chorus': chorus_, 
                             'Verse': verse_}
    out_part_name = None
    for part_name in part_names_variations:
        if any([variation in in_part_name for variation in part_names_variations[part_name]]):
            out_part_name = part_name
    return out_part_name

parts['Part Name 3'] = parts['Part Name 2'].apply(generalize_part_name)
parts.head()
# Out:
#         Author               Album            Song      All Singers  \
# 0  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 1  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 2  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 3  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 4  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
#
#    Part Singer Part Name                          Part Debug  \
# 0  $uicideBoy$     Intro                  Intro: Frayser Boy
# 1  $uicideBoy$   Verse 1        Verse 1: YUNG DEATH/LIL LIFE
# 2  $uicideBoy$      Hook                   Hook: Frayser Boy
# 3  $uicideBoy$   Verse 2  Verse 2: ODDY NUFF DA $NOW LEOPARD
# 4  $uicideBoy$      Hook                   Hook: Frayser Boy
#
#                                          Part Lyrics Part Name 2 Part Name 3
# 0  Hit the, hit the, hit the—\nHit the tone, cock...       intro       Intro
# 1  Bitches know I got the vendetta\nRollin' up th...     verse 1       Verse
# 2  Hit the tone, cock it back, ho, I gotta holla ...        hook        Hook
# 3  Here I come to paint it grey\nWhip look like I...     verse 2       Verse
# 4  Hit the tone, cock it back, ho, I gotta holla ...        hook        Hook

# %%
def correct_part_name(parts):
    all_singers = parts['All Singers']
    part_singer = parts['Part Singer']
    part_name = parts['Part Name']
    new_part_singer = part_singer
    new_part_name = part_name 
    if part_name in all_singers:
        new_part_singer = part_name
        new_part_name = 'Verse'
    elif part_singer in part_name:
        new_part_singer = part_singer
        new_part_name = 'Verse'
    return new_part_singer, new_part_name

# %%
parts['Part Name 3'].value_counts(dropna=False)
# Out:
# Verse      92971
# Chorus     85965
# Hook       23321
# Bridge     14332
# Intro      14060
# Outro      12663
# NaN         7635
# Other       2534
# Refrain     2176
# Skit         273
# Name: Part Name 3, dtype: int64

# %%
null_index = parts[pd.isna(parts['Part Name 3'])].index
res = parts.loc[null_index].apply(correct_part_name, axis=1)
parts.loc[null_index, 'Part Singer'] = res.apply(lambda x: x[0])
parts.loc[null_index, 'Part Name 3'] = res.apply(lambda x: x[1])

parts['Part Name 3'] = parts['Part Name 3'].apply(generalize_part_name)
parts['Part Name'] = parts['Part Name 3']
parts.drop(['Part Name 2', 'Part Name 3'], axis=1, inplace=True)

# %%
parts['Part Name'].value_counts(dropna=False)
# Out:
# Verse      96763
# Chorus     85965
# Hook       23321
# Bridge     14332
# Intro      14060
# Outro      12663
# NaN         3843
# Other       2534
# Refrain     2176
# Skit         273
# Name: Part Name, dtype: int64

# %%
null_index = parts[pd.isna(parts['Part Name'])].index
parts['Part Debug'] = parts['Part Debug'].apply(lambda x: format_part_name(x))
parts['Part Name 2'] = parts['Part Debug'].apply(generalize_part_name)
null_index = parts[pd.isna(parts['Part Name']) & pd.notna(parts['Part Name 2'])].index
parts['Part Name'].loc[null_index] = parts['Part Name 2'].loc[null_index]

parts = parts[['Author', 'Album', 'Song', 'All Singers', 'Part Singer', 'Part Name', 'Part Lyrics']]

# %%
parts['Part Name'].value_counts(dropna=False)
# Out:
# Verse      96779
# Chorus     85977
# Hook       23325
# Bridge     14334
# Intro      14062
# Outro      12665
# NaN         3781
# Other       2558
# Refrain     2176
# Skit         273
# Name: Part Name, dtype: int64

# %%
parts.head()
# Out:
#         Author               Album            Song      All Singers  \
# 0  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 1  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 2  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 3  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
# 4  $uicideBoy$  7th or St. Tammany  Dead Batteries  ['$uicideBoy$']
#
#    Part Singer Part Name                                        Part Lyrics
# 0  $uicideBoy$     Intro  Hit the, hit the, hit the—\nHit the tone, cock...
# 1  $uicideBoy$     Verse  Bitches know I got the vendetta\nRollin' up th...
# 2  $uicideBoy$      Hook  Hit the tone, cock it back, ho, I gotta holla ...
# 3  $uicideBoy$     Verse  Here I come to paint it grey\nWhip look like I...
# 4  $uicideBoy$      Hook  Hit the tone, cock it back, ho, I gotta holla ...

# %%
parts.shape
# Out:
# (255930, 7)

# %%
parts[(parts['Author'] == 'Monetochka') & (True)]
# Out:
#             Author                                              Album  \
# 156331  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156332  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156333  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156334  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156335  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156336  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156337  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156338  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156339  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156340  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156341  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156342  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156343  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156344  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156345  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156346  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156347  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156348  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156349  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156350  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156351  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156352  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156353  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156354  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156355  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156356  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156357  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156358  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156359  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# 156360  Monetochka      Раскраски для взрослых (Adult Coloring Books)
# ...            ...                                                ...
# 156446  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156447  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156448  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156449  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156450  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156451  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156452  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156453  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156454  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156455  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156456  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156457  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156458  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156459  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156460  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156461  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156462  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156463  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156464  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156465  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156466  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156467  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156468  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156469  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156470  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156471  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156472  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156473  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156474  Monetochka  ​психоделический клауд рэп (psychedelic cloud ...
# 156343  Если б мне платили каждый раз\nКаждый раз, ког...
# 156344  Ветру тащить нас тяжело\nВетер роняет нас на х...
# 156345  Хочешь раздеться… Стой, не спускайся вниз\nЗал...
# 156346  Кафельные зубы скалишь, подняла футболку\nМанд...
# 156347  Хочешь раздеться… Стой, не спускайся вниз\nЗал...
# 156348  (No money)\nНет монет, монет, монет, монет нет...
# 156349  Где-то модели щебечут на верхнем этаже\nГламур...
# 156350  На дороге жизни не очень мне-е-е\nРаздаю листо...
# 156351  Нет монет, монет (монет), монет (манер), монет...
# 156352  Вылез дядя, кипишуя\nПроложил мне вверх дорогу...
# 156353  Действую на них, как яд\nОни кликают меня в ай...
# 156354  Нет монет, монет (монет), монет (манер), монет...
# 156355  — Монет нет\n— Ты биты писала! Кто тебе разреш...
# 156356  Где-то модели стрекочут — они всегда в слоу-мо...
# 156357  С Небес допеваю последний хит\nЯ новый Лил Пип...
# 156358  Соседа сланцы протёрлись о бетон\nХочу подрать...
# 156359  Я вышел из дома в чужом пальто\nРайон незнаком...
# 156360  Вон в подворотне прохожий тоже пьян\nГлазеют о...
# ...                                                   ...
# 156446  Всё накалилось в семье у нас\nДо невозможности...
# 156447  Ля-ля-ля-ля-ля, ля-ля-ля-ля\nЛя-ля-ля-ля-ля, л...
# 156448  Если хочешь модным быть, купи айфончик в Apple...
# 156449  Я за эти кальсоны тебе отдала бы максимум тыщу...
# 156450  Я не видела кальсоны, увы, я не трогала этих н...
# 156451  Я за эти кальсоны тебе отдала бы максимум тыщу...
# 156452  Мой парень — самый клёвый анархо-коммунист\nОн...
# 156453  Все девочки считают, что их парни хороши\nНо м...
# 156454  Мой парень — самый клёвый анархо-коммунист\nОн...
# 156455  Он — представитель новой молодёжи:\nНе покупае...
# 156456  Мой парень — самый клёвый анархо-коммунист\nОн...
# 156457  Мы купили апельсин, он у нас всего один\nНо ег...
# 156458  Сегодня будет праздник контранасилия\nМы уже с...
# 156459  Мы купили апельсин, он у нас всего один\nНо ег...
# 156460  Лолечки лижут мне ножки всегда\nЯ бейба из гет...
# 156461  Все знают с кем хайпит монетка —\nС «Гошей Руб...
# 156462  Лолечки лижут мне ножки всегда\nЯ бейба из гет...
# 156463  Жизненный цикл лосося поражает\nВедь в пресных...
# 156464  Бессмысленно двигаясь к своей кончине\nЛосось ...
# 156465  Но зачем-то он живёт\nПо дороге вдаль плывёт\n...
# 156466  Бессмысленно двигаясь к своей кончине\nЛосось ...
# 156467  Ля-ля-ля-ля-ля-ля-ля\nЛя-ля-ля-ля-ля-ля-ля\nЛя...
# 156468  В три года я подписан был на группу «Позитифф»...
# 156469  Нежный возраст: не взрослые и не дети\nНас пог...
# 156470  Пара-пам-пам, пара-пам-пам\nПара-пам-пам, пара...
# 156471  Мне 15 лет и болит голова\nВокруг так много кл...
# 156472  Нежный возраст: не взрослые и не дети\nНас пог...
# 156473  Пара-пам-пам, пара-пам-пам\nПара-пам-пам, пара...
# 156474  За деньги девичью грудь мяли грязные, толстые ...
# 156475  За деньги, за деньги, за деньги\nЗа деньги, за...
#
# [145 rows x 7 columns]

# %%
# parts.to_csv('parts_dataset.csv')
