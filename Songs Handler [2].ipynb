# %%
import pandas as pd
import numpy as np
import os
import re

# %%
def get_part_lyrics(part):
    part = part[1:]
    return '\n'.join(part)

# %%
def get_part_info(part, all_singers, author, album, song):
    singer = None
    brackets = part[0]
    brackets_parts = brackets[1:-1].split(':')
    if len(brackets_parts) == 1:
        singer = all_singers[0]
        part_name = brackets_parts[0].strip()
    else:
        part_singers = brackets_parts[1]
        part_singers = list(map(str.strip, re.split(',|&', part_singers)))
        for part_singer in part_singers:
            if part_singer in all_singers:
                singer = part_singer
                break
        part_name = brackets_parts[0]
    part_lyrics = get_part_lyrics(part)
    if part_lyrics == '' or not singer:
        return None
    return [author, album, song, singer, part_name, part_lyrics]

# %%
song_pathes = ['Kanye West_NBA 2K13 Soundtrack_Mercy_2 Chainz_Pusha T_Big Sean.txt',
               'Logic_Confessions of a Dangerous Mind_Homicide_Eminem.txt',
               'Eminem_Kamikaze_Venom.txt',
               'Lil Pump_Lil Pump_Gucci Gang.txt']

songs_info = []

for song_path in song_pathes:
    song_text = open(f'lyrics_examples/{song_path}').read()
    author, album, song, *feats = os.path.splitext(song_path)[0].split('_')
    all_singers = [author] + feats
    
    indices = [i for i, ltr in enumerate(song_text) if ltr == '[' and song_text[i-1] == '\n'] + [len(song_text)]
    song_parts = [song_text[indices[i]:indices[i+1]].strip().split('\n') for i, index in enumerate(indices[:-1])]
    song_parts_info = [get_part_info(song_part, all_singers, author, album, song) for song_part in song_parts]
    song_parts_info = filter(None, song_parts_info)
    song_parts_info
    
    songs_info.extend(song_parts_info)

songs_info_df = pd.DataFrame(songs_info, columns=['Author', 'Album', 'Song', 'Singer', 'Song Part', 'Lyrics'])
songs_info_df
# Out:
#         Author                            Album        Song      Singer  \
# 0   Kanye West              NBA 2K13 Soundtrack       Mercy    Big Sean
# 1   Kanye West              NBA 2K13 Soundtrack       Mercy    Big Sean
# 2   Kanye West              NBA 2K13 Soundtrack       Mercy    Big Sean
# 3   Kanye West              NBA 2K13 Soundtrack       Mercy    Big Sean
# 4   Kanye West              NBA 2K13 Soundtrack       Mercy     Pusha T
# 5   Kanye West              NBA 2K13 Soundtrack       Mercy    Big Sean
# 6   Kanye West              NBA 2K13 Soundtrack       Mercy    Big Sean
# 7   Kanye West              NBA 2K13 Soundtrack       Mercy  Kanye West
# 8   Kanye West              NBA 2K13 Soundtrack       Mercy    2 Chainz
# 9   Kanye West              NBA 2K13 Soundtrack       Mercy    Big Sean
# 10  Kanye West              NBA 2K13 Soundtrack       Mercy    Big Sean
# 11       Logic  Confessions of a Dangerous Mind    Homicide       Logic
# 23     Intro  Yuh, ooh, brr, brr\nGucci gang, ooh\n(That's i...
# 24    Chorus  Gucci gang, Gucci gang, Gucci gang, Gucci gang...
# 25     Verse  My lean cost more than your rent, ooh (It do)\...
# 26    Chorus  Gucci gang, Gucci gang, Gucci gang, Gucci gang...

# %%
lyrics_df = pd.read_csv('res_all.csv', index_col=0)
lyrics_df.drop('album_url', axis=1, inplace=True)
lyrics_df.drop_duplicates(subset='text', keep='first', inplace=True)
lyrics_df = lyrics_df[lyrics_df['text'].apply(len) > 300]
lyrics_df.head()
# Out:
#                           album       artist featuring                 song  \
# 0  I Want to Die in New Orleans  $uicideBoy$        []           King Tulip
# 1  I Want to Die in New Orleans  $uicideBoy$        []  Bring Out Your Dead
# 2  I Want to Die in New Orleans  $uicideBoy$        []     Nicotine Patches
# 3  I Want to Die in New Orleans  $uicideBoy$        []       10,000 Degrees
# 4  I Want to Die in New Orleans  $uicideBoy$        []             122 Days
#
#                                                 text
# 0  \n\n[Interlude: Max Beck]\n"They changed so mu...
# 1  \n\n[Intro: Koopsta Knicca & YUNG MUTT]\nYou g...
# 2  \n\n[Intro (Distorted)]\nTriple 6 'till death\...
# 3  \n\n[Intro: Lil Gin]\nLoad up my big nine, now...
# 4  \n\n[Verse 1: LORD OF LONELINESS]\nUh, local b...

# %%
lyrics_df.shape
# Out:
# (34753, 5)

# %%
lyrics_df = lyrics_df[['artist', 'album', 'song', 'featuring', 'text']]
lyrics_df.columns = ['Author', 'Album', 'Song', 'Featuring', 'Lyrics']
lyrics_df.head()
# Out:
#         Author                         Album                 Song Featuring  \
# 0  $uicideBoy$  I Want to Die in New Orleans           King Tulip        []
# 1  $uicideBoy$  I Want to Die in New Orleans  Bring Out Your Dead        []
# 2  $uicideBoy$  I Want to Die in New Orleans     Nicotine Patches        []
# 3  $uicideBoy$  I Want to Die in New Orleans       10,000 Degrees        []
# 4  $uicideBoy$  I Want to Die in New Orleans             122 Days        []
#
#                                               Lyrics
# 0  \n\n[Interlude: Max Beck]\n"They changed so mu...
# 1  \n\n[Intro: Koopsta Knicca & YUNG MUTT]\nYou g...
# 2  \n\n[Intro (Distorted)]\nTriple 6 'till death\...
# 3  \n\n[Intro: Lil Gin]\nLoad up my big nine, now...
# 4  \n\n[Verse 1: LORD OF LONELINESS]\nUh, local b...

# %%
lyrics_df = lyrics_df[lyrics_df['Song'].apply(lambda x: '(Skit)' not in x and '(Live' not in x)]

# %%
lyrics_df.shape
# Out:
# (33542, 5)

# %%
lyrics_df.to_csv('songs_dataset.csv')
